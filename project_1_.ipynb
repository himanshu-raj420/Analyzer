# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu-raj420/Analyzer/blob/main/project_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/air_quality.csv')
df.head()
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149

# %%
import pandas as pd

# Input and output file names
input_csv = "/air_quality.csv"
output_csv = 'cleaned_air_quality.csv'


df = pd.read_csv("/air_quality.csv")

#file structure (columns, types)
print("File Structure:")
print(df.dtypes)
print("\n")

#top 5 rows
print("Top 5 Rows:")
print(df.head())
print("\n")

#bottom 5 rows
print("Bottom 5 Rows:")
print(df.tail())
print("\n")

# Count of unique values per column
print("Unique values per column:")
print(df.nunique())
print("\n")

# Cleaned data
cleaned = df.drop_duplicates().dropna()

# Save cleaned data to a new CSV
cleaned.to_csv(output_csv, index=False)
print(f"Cleaned data saved to {output_csv}")
# Out:
# File Structure:
# Date                int64
# Month               int64
# Year                int64
# Holidays_Count      int64
# Days                int64
# PM2.5             float64
# PM10              float64
# NO2               float64
# SO2               float64
# CO                float64
# Ozone             float64
# AQI                 int64
# dtype: object
#
#
# Top 5 Rows:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149
#
#
# ...
